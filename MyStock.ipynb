# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaishnavi-cyber-blip/LEarnPython/blob/master/MyStock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas_datareader as pdr
import pandas as pd
key = 'Your Key'
df = pdr.get_data_tiingo('AAPL', api_key=key)
df.to_csv('AAPL.csv')
df = pd.read_csv('AAPL.csv')

# %%
df.head()
# Out:
#   symbol                       date   close  ...  adjVolume  divCash  splitFactor
# 0   AAPL  2016-07-29 00:00:00+00:00  104.21  ...  110934752     0.00          1.0
# 1   AAPL  2016-08-01 00:00:00+00:00  106.05  ...  152671484     0.00          1.0
# 2   AAPL  2016-08-02 00:00:00+00:00  104.48  ...  135266224     0.00          1.0
# 3   AAPL  2016-08-03 00:00:00+00:00  105.79  ...  120810564     0.00          1.0
# 4   AAPL  2016-08-04 00:00:00+00:00  105.87  ...  109634600     0.57          1.0
#
# [5 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1257 entries, 0 to 1256
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1257 non-null   object
#  1   date         1257 non-null   object
#  2   close        1257 non-null   float64
#  3   high         1257 non-null   float64
#  4   low          1257 non-null   float64
#  5   open         1257 non-null   float64
#  6   volume       1257 non-null   int64
#  7   adjClose     1257 non-null   float64
#  8   adjHigh      1257 non-null   float64
#  9   adjLow       1257 non-null   float64
#  10  adjOpen      1257 non-null   float64
#  11  adjVolume    1257 non-null   int64
#  12  divCash      1257 non-null   float64
#  13  splitFactor  1257 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.6+ KB

# %%
df.isna()    #Checking if dataset has missing values :) if true: missing else: false
# Out:
#       symbol   date  close   high  ...  adjOpen  adjVolume  divCash  splitFactor
# 0      False  False  False  False  ...    False      False    False        False
# 1      False  False  False  False  ...    False      False    False        False
# 2      False  False  False  False  ...    False      False    False        False
# 3      False  False  False  False  ...    False      False    False        False
# 4      False  False  False  False  ...    False      False    False        False
# ...      ...    ...    ...    ...  ...      ...        ...      ...          ...
# 1252   False  False  False  False  ...    False      False    False        False
# 1253   False  False  False  False  ...    False      False    False        False
# 1254   False  False  False  False  ...    False      False    False        False
# 1255   False  False  False  False  ...    False      False    False        False
# 1256   False  False  False  False  ...    False      False    False        False
#
# ...

# %%
from sklearn.model_selection import  train_test_split

# %%
df1 = df.reset_index()['adjClose']
df1
# Out:
# 0        24.334436
# 1        24.764101
# 2        24.397485
# 3        24.703388
# 4        24.855171
#            ...
# 1252    145.400000
# 1253    146.800000
# 1254    148.560000
# 1255    148.990000
# 1256    146.770000
# Name: adjClose, Length: 1257, dtype: float64

# %%
df1
# Out:
# 0        24.334436
# 1        24.764101
# 2        24.397485
# 3        24.703388
# 4        24.855171
#            ...
# 1252    145.400000
# 1253    146.800000
# 1254    148.560000
# 1255    148.990000
# 1256    146.770000
# Name: adjClose, Length: 1257, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.plot(df1)

# %%
training_size = int(len(df1)*0.67)
test_size = len(df1)-training_size
train_data = df1[0:training_size]
test_data = df1[training_size:]

# %%
test_data
# Out:
# 842      64.101705
# 843      64.667490
# 844      65.616230
# 845      66.883687
# 846      65.947301
#            ...
# 1252    145.400000
# 1253    146.800000
# 1254    148.560000
# 1255    148.990000
# 1256    146.770000
# Name: adjClose, Length: 415, dtype: float64

# %%
train_data.shape
# Out:
# (842,)

# %%
training_size,test_size
# Out:
# (842, 415)

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np
train_data = np.array(train_data).reshape(-1, 1)

# %%
print(train_data.shape)
# Out:
# (842, 1)

# %%
from sklearn import preprocessing
X_data = train_data
standard = preprocessing.scale(X_data)
print(standard)
# Out:
# [[-1.80166059e+00]
#  [-1.75619246e+00]
#  [-1.79498864e+00]
#  [-1.76261731e+00]
#  [-1.74655519e+00]
#  [-1.70655638e+00]
#  [-1.68444524e+00]
#  [-1.67351388e+00]
#  [-1.69363751e+00]
#  [-1.69537659e+00]
#  [-1.68916559e+00]
#  [-1.65686842e+00]
#  [-1.65935281e+00]
#  [-1.66332785e+00]
#  [-1.66680601e+00]
#  [-1.65984969e+00]
#  [-1.68096708e+00]
#  [-1.67252013e+00]
#  [-1.69289219e+00]
#  [-1.70432042e+00]
#  [-1.71997213e+00]
#  [-1.72295341e+00]
#  [-1.74332548e+00]
#  [-1.74084108e+00]
#  [-1.72518937e+00]
#  [-1.70034539e+00]
#  [-1.70109071e+00]
#  [-1.68469368e+00]
#  [-1.75525059e+00]
#  [-1.81462771e+00]
#  [-1.75723811e+00]
#  [-1.69487971e+00]
#  [-1.59997570e+00]
#  [-1.50556856e+00]
#  [-1.52171715e+00]
#  [-1.55500809e+00]
#  [-1.55525653e+00]
#  [-1.55575341e+00]
#  [-1.52917034e+00]
#  [-1.57662235e+00]
#  [-1.57239887e+00]
#  [-1.56718164e+00]
#  [-1.54581581e+00]
#  [-1.58978966e+00]
#  [-1.56817540e+00]
#  [-1.58134271e+00]
#  [-1.56941760e+00]
# ...

# %%
plt.plot(standard)

# %%
# Applying Lstm
